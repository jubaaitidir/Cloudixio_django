# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
connection= sqlite3.connect('autopilot_new_v1.db3')
cursor=connection.execute("""SELECT name FROM sqlite_master WHERE type='table';""")

for row in cursor:
    print("table : ", row[0])
# Out:
# table :  activitesMissions
# table :  activitesType
# table :  missionsType
# table :  sqlite_sequence
# table :  competences
# table :  semaine
# table :  consultantsCompetences
# table :  timeSheet
# table :  django_migrations
# table :  auth_group_permissions
# table :  auth_user_groups
# table :  auth_user_user_permissions
# table :  django_admin_log
# table :  django_content_type
# table :  auth_permission
# table :  auth_group
# table :  auth_user
# table :  django_session
# table :  consultant
# table :  missions
# table :  clients
# table :  RapportActivite
# table :  ImportTimeSheet

# %%
df=pd.read_csv('rapports_sur_les_activites_01_01_2022_21_03_2022.csv',sep=";")
df.head()
# Out:
#    Nom complet Département  Code Clients Nom Clients  Code Projet/Régie  \
# 0  Eric Ceyral     CONSEIL            18        ISAI                181
# 1  Eric Ceyral     CONSEIL            58       Lares                581
# 2  Eric Ceyral     CONSEIL             1   Cloudixio                 15
# 3  Eric Ceyral     CONSEIL             1   Cloudixio                 17
# 4  Eric Ceyral     CONSEIL           170      Pandat               1702
#
#          Nom Projet/Régie  Code Phase/Mission       Nom Phase/Mission  \
# 0               BMAT - DD                1811               BMAT - DD
# 1               VDD Lares                5811               VDD Lares
# 2  Avant-vente/commercial                 151  Avant-vente/commercial
# 3          Projet interne                 172             ERP interne
# 4  Pandat - Base de Deals               17021           Design Sprint
#
#    Code Tâche Nom Tâche Date de début Date de fin Temps imputé (Jours)
# 0         NaN       NaN    01/01/2022  21/03/2022                 7,75
# 1         NaN       NaN    01/01/2022  21/03/2022                13,25
# 2         NaN       NaN    01/01/2022  21/03/2022                 1,75
# 3         NaN       NaN    01/01/2022  21/03/2022                    7
# 4         NaN       NaN    01/01/2022  21/03/2022                 5,75

# %%
df.isnull().sum()
# Out:
#  Nom complet             0
# Département              0
# Code Clients             0
# Nom Clients              0
# Code Projet/Régie        0
# Nom Projet/Régie         0
# Code Phase/Mission       0
# Nom Phase/Mission        0
# Code Tâche              30
# Nom Tâche               30
# Date de début            0
# Date de fin              0
# Temps imputé (Jours)     0
# dtype: int64

# %%
df.describe()
# Out:
#        Code Clients  Code Projet/Régie  Code Phase/Mission     Code Tâche
# count     44.000000          44.000000           44.000000      14.000000
# mean      73.386364         736.090909         7362.272727  131541.000000
# std       76.963058         768.553453         7685.291081   70271.405416
# min        1.000000          11.000000          111.000000    1111.000000
# 25%        1.000000          15.000000          151.000000  155111.250000
# 50%       44.000000         441.000000         4411.500000  171112.000000
# 75%      170.000000        1701.250000        17014.250000  171113.000000
# max      192.000000        1921.000000        19211.000000  171114.000000

# %%
len(df)
# Out:
# 44

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0    Nom complet          44 non-null     object
#  1   Département           44 non-null     object
#  2   Code Clients          44 non-null     int64
#  3   Nom Clients           44 non-null     object
#  4   Code Projet/Régie     44 non-null     int64
#  5   Nom Projet/Régie      44 non-null     object
#  6   Code Phase/Mission    44 non-null     int64
#  7   Nom Phase/Mission     44 non-null     object
#  8   Code Tâche            14 non-null     float64
#  9   Nom Tâche             14 non-null     object
#  10  Date de début         44 non-null     object
#  11  Date de fin           44 non-null     object
#  12  Temps imputé (Jours)  44 non-null     object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 4.6+ KB

# %%
nb_null= df['Nom Tâche'].isnull().sum()
nb_null
# Out:
# 30

# %%
df['Nom Tâche'].unique()
# Out:
# array([nan,
#        'Application Hébergement et restauration (rédaction CDC, atelier)',
#        'Parcours de formation', 'Hors SmartCapital / CloudixIO',
#        'Application Changement de ville (recette)', 'KT Project Office',
#        'KT S4M  Conversion to S/4', 'KT SAP Smart ToolBox',
#        'Mise en place partenariat HubSpot'], dtype=object)

# %%
df['Temps imputé (Jours)']=[x[1].replace(',','.') for x in df['Temps imputé (Jours)'].items()]
df['Temps imputé (Jours)']= df['Temps imputé (Jours)'].astype('float64')

# %%
df['Temps imputé (Jours)'].head()
# Out:
# 0     7.75
# 1    13.25
# 2     1.75
# 3     7.00
# 4     5.75
# Name: Temps imputé (Jours), dtype: float64

# %%
df.columns
# Out:
# Index([' Nom complet', 'Département', 'Code Clients', 'Nom Clients',
#        'Code Projet/Régie', 'Nom Projet/Régie', 'Code Phase/Mission',
#        'Nom Phase/Mission', 'Code Tâche', 'Nom Tâche', 'Date de début',
#        'Date de fin', 'Temps imputé (Jours)'],
#       dtype='object')

# %%
df['Code Tâche']=df['Code Tâche'].fillna(0.0)

# %%
df['Nom Tâche']=df['Nom Tâche'].fillna(" ")

# %%
df.head()
# Out:
#    Nom complet Département  Code Clients Nom Clients  Code Projet/Régie  \
# 0  Eric Ceyral     CONSEIL            18        ISAI                181
# 1  Eric Ceyral     CONSEIL            58       Lares                581
# 2  Eric Ceyral     CONSEIL             1   Cloudixio                 15
# 3  Eric Ceyral     CONSEIL             1   Cloudixio                 17
# 4  Eric Ceyral     CONSEIL           170      Pandat               1702
#
#          Nom Projet/Régie  Code Phase/Mission       Nom Phase/Mission  \
# 0               BMAT - DD                1811               BMAT - DD
# 1               VDD Lares                5811               VDD Lares
# 2  Avant-vente/commercial                 151  Avant-vente/commercial
# 3          Projet interne                 172             ERP interne
# 4  Pandat - Base de Deals               17021           Design Sprint
#
#    Code Tâche Nom Tâche Date de début Date de fin  Temps imputé (Jours)
# 0         0.0              01/01/2022  21/03/2022                  7.75
# 1         0.0              01/01/2022  21/03/2022                 13.25
# 2         0.0              01/01/2022  21/03/2022                  1.75
# 3         0.0              01/01/2022  21/03/2022                  7.00
# 4         0.0              01/01/2022  21/03/2022                  5.75

# %%
df['Département'].head()
# Out:
# 0    CONSEIL
# 1    CONSEIL
# 2    CONSEIL
# 3    CONSEIL
# 4    CONSEIL
# Name: Département, dtype: object

# %%
plt.figure(figsize=(20,10))
#df_filtered= df[df.Département=="CONSEIL"]
df_filtered=df.groupby('Département')['Code Clients','Code Phase/Mission'].nunique()
sns.barplot(data=df_filtered)
# Out:
# C:\Users\jubaa\AppData\Local\Temp/ipykernel_98796/4041889191.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_filtered=df.groupby('Département')['Code Clients','Code Phase/Mission'].nunique()
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
#  Nom complet            0
# Département             0
# Code Clients            0
# Nom Clients             0
# Code Projet/Régie       0
# Nom Projet/Régie        0
# Code Phase/Mission      0
# Nom Phase/Mission       0
# Code Tâche              0
# Nom Tâche               0
# Date de début           0
# Date de fin             0
# Temps imputé (Jours)    0
# dtype: int64

# %%
df.head()
# Out:
#    Nom complet Département  Code Clients Nom Clients  Code Projet/Régie  \
# 0  Eric Ceyral     CONSEIL            18        ISAI                181
# 1  Eric Ceyral     CONSEIL            58       Lares                581
# 2  Eric Ceyral     CONSEIL             1   Cloudixio                 15
# 3  Eric Ceyral     CONSEIL             1   Cloudixio                 17
# 4  Eric Ceyral     CONSEIL           170      Pandat               1702
#
#          Nom Projet/Régie  Code Phase/Mission       Nom Phase/Mission  \
# 0               BMAT - DD                1811               BMAT - DD
# 1               VDD Lares                5811               VDD Lares
# 2  Avant-vente/commercial                 151  Avant-vente/commercial
# 3          Projet interne                 172             ERP interne
# 4  Pandat - Base de Deals               17021           Design Sprint
#
#    Code Tâche Nom Tâche Date de début Date de fin  Temps imputé (Jours)
# 0         0.0              01/01/2022  21/03/2022                  7.75
# 1         0.0              01/01/2022  21/03/2022                 13.25
# 2         0.0              01/01/2022  21/03/2022                  1.75
# 3         0.0              01/01/2022  21/03/2022                  7.00
# 4         0.0              01/01/2022  21/03/2022                  5.75

# %%
#df_test=df.groupby('Code Clients')
df['Temps imputé client']=df.groupby('Code Clients').sum()
df['Temps imputé client']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_98796/3287017023.py in <module>
#       1 #df_test=df.groupby('Code Clients')
# ----> 2 df['Temps imputé client']=df.groupby('Code Clients').sum()
#       3 df['Temps imputé client']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3600             self._setitem_array(key, value)
#    3601         elif isinstance(value, DataFrame):
# -> 3602             self._set_item_frame_value(key, value)
#    3603         elif (
#    3604             is_list_like(value)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item_frame_value(self, key, value)
#    3727             len_cols = 1 if is_scalar(cols) else len(cols)
#    3728             if len_cols != len(value.columns):
# -> 3729                 raise ValueError("Columns must be same length as key")
#    3730
#    3731             # align right-hand-side columns if self.columns
#
# ValueError: Columns must be same length as key

# %%
df_temps_per_client=df.groupby('Code Clients',as_index =False).agg({'Temps imputé (Jours)':'sum'})
df_temps_per_client
# Out:
#     Code Clients  Temps imputé (Jours)
# 0              1                 86.25
# 1              3                  9.00
# 2             18                  7.75
# 3             30                 55.50
# 4             58                 13.25
# 5             59                 22.75
# 6             61                 25.50
# 7             65                 14.00
# 8            130                 13.00
# 9            155                 35.00
# 10           170                 49.75
# 11           171                110.25
# 12           192                  0.50

# %%
df_temps_per_client.head()
# Out:
#    Code Clients  Temps imputé (Jours)
# 0             1                 86.25
# 1             3                  9.00
# 2            18                  7.75
# 3            30                 55.50
# 4            58                 13.25

# %%
sns.barplot(x='Code Clients',y='Temps imputé (Jours)',data=df_temps_per_client)
# Out:
# <AxesSubplot:xlabel='Code Clients', ylabel='Temps imputé (Jours)'>

# %%
df_temps_per_client.dtypes
# Out:
# Code Clients              int64
# Temps imputé (Jours)    float64
# dtype: object

# %%
list_consultant=connection.execute("""SELECT * FROM consultant""")

for row in list_consultant:
    print("consultant = ", row[0], row[1],row[2],row[3])
# Out:
# consultant =  1 Ceyral Eric eric.ceyral@cloudixio.com
# consultant =  2 Maindron Mickael None
# consultant =  3 Roussel David None
# consultant =  4 Ricart Olivier None
# consultant =  5 Catania Gorka None
# consultant =  6 Jean-Denis Gorkin None
# consultant =  7 Chacha Ahmed-Yassin None
# consultant =  8 Beback Hal None
# consultant =  9 test Jérôme None

# %%
list_missions=connection.execute("""SELECT * FROM missions""")

for row in list_missions:
    print("mission = ", row[0], row[1],row[2],row[3],row[4])
# Out:
# mission =  1 1 2022-01-10 00:00:00 2022-02-19 00:00:00 LARES VDD
# mission =  2 2 2021-12-16 2022-02-19 ISAI BMAT
# mission =  3 6 2022-02-01 00:00:00 2022-07-31 00:00:00 Autopilot : ERP Interne Cloudixio
# mission =  4 4 2022-02-08 2022-03-25 PANDAT - Base de deals
# mission =  5 2 2022-03-14 2022-04-30 Mouratoglou

# %%
list_competences_consultants=connection.execute("""SELECT * FROM consultantsCompetences
  """)

for row in list_competences_consultants:
    print("competences consultants = ", row[0], row[1],row[2])
# Out:
# competences consultants =  8 1 1
# competences consultants =  2 1 2
# competences consultants =  8 2 3
# competences consultants =  3 2 4
# competences consultants =  4 1 5
# competences consultants =  8 3 6
# competences consultants =  3 1 7
# competences consultants =  10 1 8
# competences consultants =  9 7 9
# competences consultants =  1 9 10
# competences consultants =  5 6 11
# competences consultants =  6 6 12
# competences consultants =  1 8 13
# competences consultants =  2 8 14
# competences consultants =  7 8 15
# competences consultants =  2 6 16
# competences consultants =  1 6 17

# %%
list_competences_consultants=connection.execute("""PRAGMA table_info("missions");
  """)

for row in list_competences_consultants:
    print("columns = ", row[1])
# Out:
# columns =  idMission
# columns =  idMissionType
# columns =  startDate
# columns =  endDate
# columns =  nomMission
# columns =  idMissionLucca

# %%
list_timesheet=connection.execute("""SELECT * FROM TIMESHEET""");

print('         idTimeSheet idMission')
for row in list_timesheet:

    print(" Timesheet:  ", row[0],"        ",row[1])
# Out:
#          idTimeSheet idMission
#  Timesheet:   1          1
#  Timesheet:   2          2
#  Timesheet:   3          2
#  Timesheet:   4          1
#  Timesheet:   5          1
#  Timesheet:   6          1
#  Timesheet:   7          1
#  Timesheet:   8          1
#  Timesheet:   9          1
#  Timesheet:   10          1
#  Timesheet:   11          1
#  Timesheet:   12          1
#  Timesheet:   13          1
#  Timesheet:   14          1
#  Timesheet:   15          2
#  Timesheet:   16          2
#  Timesheet:   17          2
#  Timesheet:   18          2
#  Timesheet:   19          2
#  Timesheet:   20          2
#  Timesheet:   21          2
#  Timesheet:   22          2
#  Timesheet:   23          2
#  Timesheet:   24          3
#  Timesheet:   25          3
#  Timesheet:   26          3
#  Timesheet:   27          3
#  Timesheet:   28          3
#  Timesheet:   29          3
#  Timesheet:   30          4
#  Timesheet:   31          4
#  Timesheet:   32          4
#  Timesheet:   33          4
#  Timesheet:   34          4
#  Timesheet:   35          4
#  Timesheet:   36          4
#  Timesheet:   39          4
#  Timesheet:   40          5

# %%
list_timesheet=connection.execute("""SELECT * FROM RapportActivite""");

print('                      nom          Département')
for row in list_timesheet:

    print(" Rapport Activite :  ", row[0],"        ",row[1])
# Out:
#                       nom          Département
#  Rapport Activite :   Test          Departement
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Nicolas Entressangle          DELIVERY
#  Rapport Activite :   Nicolas Entressangle          DELIVERY
#  Rapport Activite :   Nicolas Entressangle          DELIVERY
#  Rapport Activite :   Nicolas Entressangle          DELIVERY
#  Rapport Activite :   Nicolas Entressangle          DELIVERY
#  Rapport Activite :   Nicolas Entressangle          DELIVERY
#  Rapport Activite :   Olivia Faraut          SOFTWARE
#  Rapport Activite :   Olivia Faraut          SOFTWARE
#  Rapport Activite :   Olivia Faraut          SOFTWARE
#  Rapport Activite :   Cécile Prayer          DELIVERY
#  Rapport Activite :   Cécile Prayer          DELIVERY
#  Rapport Activite :   Cécile Prayer          DELIVERY
#  Rapport Activite :   Jorge Regada          DELIVERY
#  Rapport Activite :   Jorge Regada          DELIVERY
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Raymond Salmon          DELIVERY
#  Rapport Activite :   Raymond Salmon          DELIVERY
#  Rapport Activite :   Léonard Sené          DELIVERY
#  Rapport Activite :   Léonard Sené          DELIVERY
#  Rapport Activite :   Marc-Antoine Sené          DELIVERY
#  Rapport Activite :   Marc-Antoine Sené          DELIVERY
#  Rapport Activite :   Marc-Antoine Sené          DELIVERY
#  Rapport Activite :   Pierre Sordoillet          DELIVERY
#  Rapport Activite :   Damien Tardieu          CONSEIL
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Test          Departement
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Nicolas Entressangle          DELIVERY
#  Rapport Activite :   Nicolas Entressangle          DELIVERY
#  Rapport Activite :   Nicolas Entressangle          DELIVERY
#  Rapport Activite :   Nicolas Entressangle          DELIVERY
#  Rapport Activite :   Nicolas Entressangle          DELIVERY
#  Rapport Activite :   Nicolas Entressangle          DELIVERY
#  Rapport Activite :   Olivia Faraut          SOFTWARE
#  Rapport Activite :   Olivia Faraut          SOFTWARE
#  Rapport Activite :   Olivia Faraut          SOFTWARE
#  Rapport Activite :   Cécile Prayer          DELIVERY
#  Rapport Activite :   Cécile Prayer          DELIVERY
#  Rapport Activite :   Cécile Prayer          DELIVERY
#  Rapport Activite :   Jorge Regada          DELIVERY
#  Rapport Activite :   Jorge Regada          DELIVERY
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Raymond Salmon          DELIVERY
#  Rapport Activite :   Raymond Salmon          DELIVERY
#  Rapport Activite :   Léonard Sené          DELIVERY
#  Rapport Activite :   Léonard Sené          DELIVERY
#  Rapport Activite :   Marc-Antoine Sené          DELIVERY
#  Rapport Activite :   Marc-Antoine Sené          DELIVERY
#  Rapport Activite :   Marc-Antoine Sené          DELIVERY
#  Rapport Activite :   Pierre Sordoillet          DELIVERY
#  Rapport Activite :   Damien Tardieu          CONSEIL
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Test          Departement
#  Rapport Activite :   Test          Departement
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Eric Ceyral          CONSEIL
#  Rapport Activite :   Nicolas Entressangle          DELIVERY
#  Rapport Activite :   Nicolas Entressangle          DELIVERY
#  Rapport Activite :   Nicolas Entressangle          DELIVERY
#  Rapport Activite :   Nicolas Entressangle          DELIVERY
#  Rapport Activite :   Nicolas Entressangle          DELIVERY
#  Rapport Activite :   Nicolas Entressangle          DELIVERY
#  Rapport Activite :   Olivia Faraut          SOFTWARE
#  Rapport Activite :   Olivia Faraut          SOFTWARE
#  Rapport Activite :   Olivia Faraut          SOFTWARE
#  Rapport Activite :   Cécile Prayer          DELIVERY
#  Rapport Activite :   Cécile Prayer          DELIVERY
#  Rapport Activite :   Cécile Prayer          DELIVERY
#  Rapport Activite :   Jorge Regada          DELIVERY
#  Rapport Activite :   Jorge Regada          DELIVERY
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Olivier Ricart          CONSEIL
#  Rapport Activite :   Raymond Salmon          DELIVERY
#  Rapport Activite :   Raymond Salmon          DELIVERY
#  Rapport Activite :   Léonard Sené          DELIVERY
#  Rapport Activite :   Léonard Sené          DELIVERY
#  Rapport Activite :   Marc-Antoine Sené          DELIVERY
#  Rapport Activite :   Marc-Antoine Sené          DELIVERY
#  Rapport Activite :   Marc-Antoine Sené          DELIVERY
#  Rapport Activite :   Pierre Sordoillet          DELIVERY
#  Rapport Activite :   Damien Tardieu          CONSEIL
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY
#  Rapport Activite :   Aurélien Vion          DELIVERY

# %%
strSql = """
INSERT INTO RapportActivite(
    NomComplet,
    Departement,
    CodeClient,
    NomClient,
    CodeProjetRegie,
    NomProjetRegie,
    CodePhaseMission,
    NomPhaseMission,
    CodeTacheMission,
    NomTacheMission,
    DateDebut,
    DateFin,
    TempImpute
) 
VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?)"""
#print(strSql)
cursor.execute(strSql, ("Test", "Departement", 12, "Nom Client", "CodeProjet","NomProjet","CodePhaseMission","NomPhaseMission","CodeTache","NomTach",100000,10000,2))

def printChamp(strChamp):
    if type(row[strChamp]) == "string":
        print(strChamp+ " -> " + row[strChamp])
    else:
        print(strChamp + " -> " + row[strChamp].to_string())

for index, row in df.iterrows():
    a = {} 
    for column in df:
        print("colum name : " + column + " -> " + str(type(row[column])) + " -> " + str(row[column])) 
        a=row
    cursor.execute(strSql, row)
    print(a)
    print('-----------------------------------')
#    print("Nom Complet -> "+ row["Département"])
#Code Clients;Nom Clients;Code Projet/Régie;Nom Projet/Régie;Code Phase/Mission;Nom Phase/Mission;Code Tâche;Nom Tâche;Date de début;Date de fin;Temps imputé (Jours) 
cur.close()
conn.commit()
# Out:
# colum name :  Nom complet -> <class 'str'> -> Eric Ceyral
# colum name : Département -> <class 'str'> -> CONSEIL
# colum name : Code Clients -> <class 'int'> -> 18
# colum name : Nom Clients -> <class 'str'> -> ISAI
# colum name : Code Projet/Régie -> <class 'int'> -> 181
# colum name : Nom Projet/Régie -> <class 'str'> -> BMAT - DD
# colum name : Code Phase/Mission -> <class 'int'> -> 1811
# colum name : Nom Phase/Mission -> <class 'str'> -> BMAT - DD
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 7,75
#  Nom complet            Eric Ceyral
# Département                 CONSEIL
# Code Clients                     18
# Nom Clients                    ISAI
# Code Projet/Régie               181
# Nom Projet/Régie          BMAT - DD
# Code Phase/Mission             1811
# Nom Phase/Mission         BMAT - DD
# Code Tâche                      0.0
# Nom Tâche
# Date de début            01/01/2022
# Date de fin              21/03/2022
# Temps imputé (Jours)           7,75
# Name: 0, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Eric Ceyral
# colum name : Département -> <class 'str'> -> CONSEIL
# colum name : Code Clients -> <class 'int'> -> 58
# colum name : Nom Clients -> <class 'str'> -> Lares
# colum name : Code Projet/Régie -> <class 'int'> -> 581
# colum name : Nom Projet/Régie -> <class 'str'> -> VDD Lares
# colum name : Code Phase/Mission -> <class 'int'> -> 5811
# colum name : Nom Phase/Mission -> <class 'str'> -> VDD Lares
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 13,25
#  Nom complet            Eric Ceyral
# Département                 CONSEIL
# Code Clients                     58
# Nom Clients                   Lares
# Code Projet/Régie               581
# Nom Projet/Régie          VDD Lares
# Code Phase/Mission             5811
# Nom Phase/Mission         VDD Lares
# Code Tâche                      0.0
# Nom Tâche
# Date de début            01/01/2022
# Date de fin              21/03/2022
# Temps imputé (Jours)          13,25
# Name: 1, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Eric Ceyral
# colum name : Département -> <class 'str'> -> CONSEIL
# colum name : Code Clients -> <class 'int'> -> 1
# colum name : Nom Clients -> <class 'str'> -> Cloudixio
# colum name : Code Projet/Régie -> <class 'int'> -> 15
# colum name : Nom Projet/Régie -> <class 'str'> -> Avant-vente/commercial
# colum name : Code Phase/Mission -> <class 'int'> -> 151
# colum name : Nom Phase/Mission -> <class 'str'> -> Avant-vente/commercial
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 1,75
#  Nom complet                       Eric Ceyral
# Département                            CONSEIL
# Code Clients                                 1
# Nom Clients                          Cloudixio
# Code Projet/Régie                           15
# Nom Projet/Régie        Avant-vente/commercial
# Code Phase/Mission                         151
# Nom Phase/Mission       Avant-vente/commercial
# Code Tâche                                 0.0
# Nom Tâche
# Date de début                       01/01/2022
# Date de fin                         21/03/2022
# Temps imputé (Jours)                      1,75
# Name: 2, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Eric Ceyral
# colum name : Département -> <class 'str'> -> CONSEIL
# colum name : Code Clients -> <class 'int'> -> 1
# colum name : Nom Clients -> <class 'str'> -> Cloudixio
# colum name : Code Projet/Régie -> <class 'int'> -> 17
# colum name : Nom Projet/Régie -> <class 'str'> -> Projet interne
# colum name : Code Phase/Mission -> <class 'int'> -> 172
# colum name : Nom Phase/Mission -> <class 'str'> -> ERP interne
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 7
#  Nom complet               Eric Ceyral
# Département                    CONSEIL
# Code Clients                         1
# Nom Clients                  Cloudixio
# Code Projet/Régie                   17
# Nom Projet/Régie        Projet interne
# Code Phase/Mission                 172
# Nom Phase/Mission          ERP interne
# Code Tâche                         0.0
# Nom Tâche
# Date de début               01/01/2022
# Date de fin                 21/03/2022
# Temps imputé (Jours)                 7
# Name: 3, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Eric Ceyral
# colum name : Département -> <class 'str'> -> CONSEIL
# colum name : Code Clients -> <class 'int'> -> 170
# colum name : Nom Clients -> <class 'str'> -> Pandat
# colum name : Code Projet/Régie -> <class 'int'> -> 1702
# colum name : Nom Projet/Régie -> <class 'str'> -> Pandat - Base de Deals
# colum name : Code Phase/Mission -> <class 'int'> -> 17021
# colum name : Nom Phase/Mission -> <class 'str'> -> Design Sprint
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 5,75
#  Nom complet                       Eric Ceyral
# Département                            CONSEIL
# Code Clients                               170
# Nom Clients                             Pandat
# Code Projet/Régie                         1702
# Nom Projet/Régie        Pandat - Base de Deals
# Code Phase/Mission                       17021
# Nom Phase/Mission                Design Sprint
# Code Tâche                                 0.0
# Nom Tâche
# Date de début                       01/01/2022
# Date de fin                         21/03/2022
# Temps imputé (Jours)                      5,75
# Name: 4, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Eric Ceyral
# colum name : Département -> <class 'str'> -> CONSEIL
# colum name : Code Clients -> <class 'int'> -> 192
# colum name : Nom Clients -> <class 'str'> -> Marsh SAS
# colum name : Code Projet/Régie -> <class 'int'> -> 1921
# colum name : Nom Projet/Régie -> <class 'str'> -> Marsh Cadrage SAM
# colum name : Code Phase/Mission -> <class 'int'> -> 19211
# colum name : Nom Phase/Mission -> <class 'str'> -> Cadrage
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 0,5
#  Nom complet                  Eric Ceyral
# Département                       CONSEIL
# Code Clients                          192
# Nom Clients                     Marsh SAS
# Code Projet/Régie                    1921
# Nom Projet/Régie        Marsh Cadrage SAM
# Code Phase/Mission                  19211
# Nom Phase/Mission                 Cadrage
# Code Tâche                            0.0
# Nom Tâche
# Date de début                  01/01/2022
# Date de fin                    21/03/2022
# Temps imputé (Jours)                  0,5
# Name: 5, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Nicolas Entressangle
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 155
# colum name : Nom Clients -> <class 'str'> -> Les Compagnons
# colum name : Code Projet/Régie -> <class 'int'> -> 1551
# colum name : Nom Projet/Régie -> <class 'str'> -> Pilotage DSI Les Compagnons
# colum name : Code Phase/Mission -> <class 'int'> -> 15511
# colum name : Nom Phase/Mission -> <class 'str'> -> PMO NEN
# colum name : Code Tâche -> <class 'float'> -> 155111.0
# colum name : Nom Tâche -> <class 'str'> -> Application Hébergement et restauration (rédaction CDC, atelier)
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 12,5
#  Nom complet                                         Nicolas Entressangle
# Département                                                      DELIVERY
# Code Clients                                                          155
# Nom Clients                                                Les Compagnons
# Code Projet/Régie                                                    1551
# Nom Projet/Régie                              Pilotage DSI Les Compagnons
# Code Phase/Mission                                                  15511
# Nom Phase/Mission                                                 PMO NEN
# Code Tâche                                                       155111.0
# Nom Tâche               Application Hébergement et restauration (rédac...
# Date de début                                                  01/01/2022
# Date de fin                                                    21/03/2022
# Temps imputé (Jours)                                                 12,5
# Name: 6, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Nicolas Entressangle
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 155
# colum name : Nom Clients -> <class 'str'> -> Les Compagnons
# colum name : Code Projet/Régie -> <class 'int'> -> 1551
# colum name : Nom Projet/Régie -> <class 'str'> -> Pilotage DSI Les Compagnons
# colum name : Code Phase/Mission -> <class 'int'> -> 15511
# colum name : Nom Phase/Mission -> <class 'str'> -> PMO NEN
# colum name : Code Tâche -> <class 'float'> -> 155113.0
# colum name : Nom Tâche -> <class 'str'> -> Parcours de formation
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 1
#  Nom complet                   Nicolas Entressangle
# Département                                DELIVERY
# Code Clients                                    155
# Nom Clients                          Les Compagnons
# Code Projet/Régie                              1551
# Nom Projet/Régie        Pilotage DSI Les Compagnons
# Code Phase/Mission                            15511
# Nom Phase/Mission                           PMO NEN
# Code Tâche                                 155113.0
# Nom Tâche                     Parcours de formation
# Date de début                            01/01/2022
# Date de fin                              21/03/2022
# Temps imputé (Jours)                              1
# Name: 7, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Nicolas Entressangle
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 1
# colum name : Nom Clients -> <class 'str'> -> Cloudixio
# colum name : Code Projet/Régie -> <class 'int'> -> 12
# colum name : Nom Projet/Régie -> <class 'str'> -> Partenariat Leapwork
# colum name : Code Phase/Mission -> <class 'int'> -> 121
# colum name : Nom Phase/Mission -> <class 'str'> -> Formation Leapwork
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 6
#  Nom complet            Nicolas Entressangle
# Département                         DELIVERY
# Code Clients                               1
# Nom Clients                        Cloudixio
# Code Projet/Régie                         12
# Nom Projet/Régie        Partenariat Leapwork
# Code Phase/Mission                       121
# Nom Phase/Mission         Formation Leapwork
# Code Tâche                               0.0
# Nom Tâche
# Date de début                     01/01/2022
# Date de fin                       21/03/2022
# Temps imputé (Jours)                       6
# Name: 8, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Nicolas Entressangle
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 3
# colum name : Nom Clients -> <class 'str'> -> Hors Smart-Capital/ Cloudixio
# colum name : Code Projet/Régie -> <class 'int'> -> 31
# colum name : Nom Projet/Régie -> <class 'str'> -> Hors Smart-Capital / CloudixIO
# colum name : Code Phase/Mission -> <class 'int'> -> 311
# colum name : Nom Phase/Mission -> <class 'str'> -> Hors Smart-Capital / CloudixIO
# colum name : Code Tâche -> <class 'float'> -> 3111.0
# colum name : Nom Tâche -> <class 'str'> -> Hors SmartCapital / CloudixIO
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 1
#  Nom complet                      Nicolas Entressangle
# Département                                   DELIVERY
# Code Clients                                         3
# Nom Clients              Hors Smart-Capital/ Cloudixio
# Code Projet/Régie                                   31
# Nom Projet/Régie        Hors Smart-Capital / CloudixIO
# Code Phase/Mission                                 311
# Nom Phase/Mission       Hors Smart-Capital / CloudixIO
# Code Tâche                                      3111.0
# Nom Tâche                Hors SmartCapital / CloudixIO
# Date de début                               01/01/2022
# Date de fin                                 21/03/2022
# Temps imputé (Jours)                                 1
# Name: 9, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Nicolas Entressangle
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 155
# colum name : Nom Clients -> <class 'str'> -> Les Compagnons
# colum name : Code Projet/Régie -> <class 'int'> -> 1551
# colum name : Nom Projet/Régie -> <class 'str'> -> Pilotage DSI Les Compagnons
# colum name : Code Phase/Mission -> <class 'int'> -> 15511
# colum name : Nom Phase/Mission -> <class 'str'> -> PMO NEN
# colum name : Code Tâche -> <class 'float'> -> 155112.0
# colum name : Nom Tâche -> <class 'str'> -> Application Changement de ville (recette)
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 0,5
#  Nom complet                                 Nicolas Entressangle
# Département                                              DELIVERY
# Code Clients                                                  155
# Nom Clients                                        Les Compagnons
# Code Projet/Régie                                            1551
# Nom Projet/Régie                      Pilotage DSI Les Compagnons
# Code Phase/Mission                                          15511
# Nom Phase/Mission                                         PMO NEN
# Code Tâche                                               155112.0
# Nom Tâche               Application Changement de ville (recette)
# Date de début                                          01/01/2022
# Date de fin                                            21/03/2022
# Temps imputé (Jours)                                          0,5
# Name: 10, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Nicolas Entressangle
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 61
# colum name : Nom Clients -> <class 'str'> -> STA
# colum name : Code Projet/Régie -> <class 'int'> -> 611
# colum name : Nom Projet/Régie -> <class 'str'> -> STA - Air France
# colum name : Code Phase/Mission -> <class 'int'> -> 6111
# colum name : Nom Phase/Mission -> <class 'str'> -> Business Analyst NEN
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 25,5
#  Nom complet            Nicolas Entressangle
# Département                         DELIVERY
# Code Clients                              61
# Nom Clients                              STA
# Code Projet/Régie                        611
# Nom Projet/Régie            STA - Air France
# Code Phase/Mission                      6111
# Nom Phase/Mission       Business Analyst NEN
# Code Tâche                               0.0
# Nom Tâche
# Date de début                     01/01/2022
# Date de fin                       21/03/2022
# Temps imputé (Jours)                    25,5
# Name: 11, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Olivia Faraut
# colum name : Département -> <class 'str'> -> SOFTWARE
# colum name : Code Clients -> <class 'int'> -> 1
# colum name : Nom Clients -> <class 'str'> -> Cloudixio
# colum name : Code Projet/Régie -> <class 'int'> -> 13
# colum name : Nom Projet/Régie -> <class 'str'> -> BU Software
# colum name : Code Phase/Mission -> <class 'int'> -> 132
# colum name : Nom Phase/Mission -> <class 'str'> -> Westaff
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 14,75
#  Nom complet            Olivia Faraut
# Département                  SOFTWARE
# Code Clients                        1
# Nom Clients                 Cloudixio
# Code Projet/Régie                  13
# Nom Projet/Régie          BU Software
# Code Phase/Mission                132
# Nom Phase/Mission             Westaff
# Code Tâche                        0.0
# Nom Tâche
# Date de début              01/01/2022
# Date de fin                21/03/2022
# Temps imputé (Jours)            14,75
# Name: 12, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Olivia Faraut
# colum name : Département -> <class 'str'> -> SOFTWARE
# colum name : Code Clients -> <class 'int'> -> 1
# colum name : Nom Clients -> <class 'str'> -> Cloudixio
# colum name : Code Projet/Régie -> <class 'int'> -> 13
# colum name : Nom Projet/Régie -> <class 'str'> -> BU Software
# colum name : Code Phase/Mission -> <class 'int'> -> 134
# colum name : Nom Phase/Mission -> <class 'str'> -> Smart Toolbox
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 11,25
#  Nom complet            Olivia Faraut
# Département                  SOFTWARE
# Code Clients                        1
# Nom Clients                 Cloudixio
# Code Projet/Régie                  13
# Nom Projet/Régie          BU Software
# Code Phase/Mission                134
# Nom Phase/Mission       Smart Toolbox
# Code Tâche                        0.0
# Nom Tâche
# Date de début              01/01/2022
# Date de fin                21/03/2022
# Temps imputé (Jours)            11,25
# Name: 13, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Olivia Faraut
# colum name : Département -> <class 'str'> -> SOFTWARE
# colum name : Code Clients -> <class 'int'> -> 65
# colum name : Nom Clients -> <class 'str'> -> Trajan Capital
# colum name : Code Projet/Régie -> <class 'int'> -> 651
# colum name : Nom Projet/Régie -> <class 'str'> -> Kraft - DD digitale
# colum name : Code Phase/Mission -> <class 'int'> -> 6511
# colum name : Nom Phase/Mission -> <class 'str'> -> Kraft - Due Diligence Digitale
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 9,5
#  Nom complet                             Olivia Faraut
# Département                                   SOFTWARE
# Code Clients                                        65
# Nom Clients                             Trajan Capital
# Code Projet/Régie                                  651
# Nom Projet/Régie                   Kraft - DD digitale
# Code Phase/Mission                                6511
# Nom Phase/Mission       Kraft - Due Diligence Digitale
# Code Tâche                                         0.0
# Nom Tâche
# Date de début                               01/01/2022
# Date de fin                                 21/03/2022
# Temps imputé (Jours)                               9,5
# Name: 14, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Cécile Prayer
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 171
# colum name : Nom Clients -> <class 'str'> -> Kering Tech
# colum name : Code Projet/Régie -> <class 'int'> -> 1711
# colum name : Nom Projet/Régie -> <class 'str'> -> KT Project Framework
# colum name : Code Phase/Mission -> <class 'int'> -> 17111
# colum name : Nom Phase/Mission -> <class 'str'> -> KT Project Framework
# colum name : Code Tâche -> <class 'float'> -> 171111.0
# colum name : Nom Tâche -> <class 'str'> -> KT Project Office
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 11,25
#  Nom complet                   Cécile Prayer
# Département                         DELIVERY
# Code Clients                             171
# Nom Clients                     Kering Tech
# Code Projet/Régie                       1711
# Nom Projet/Régie        KT Project Framework
# Code Phase/Mission                     17111
# Nom Phase/Mission       KT Project Framework
# Code Tâche                          171111.0
# Nom Tâche                  KT Project Office
# Date de début                     01/01/2022
# Date de fin                       21/03/2022
# Temps imputé (Jours)                   11,25
# Name: 15, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Cécile Prayer
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 171
# colum name : Nom Clients -> <class 'str'> -> Kering Tech
# colum name : Code Projet/Régie -> <class 'int'> -> 1711
# colum name : Nom Projet/Régie -> <class 'str'> -> KT Project Framework
# colum name : Code Phase/Mission -> <class 'int'> -> 17111
# colum name : Nom Phase/Mission -> <class 'str'> -> KT Project Framework
# colum name : Code Tâche -> <class 'float'> -> 171113.0
# colum name : Nom Tâche -> <class 'str'> -> KT S4M  Conversion to S/4
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 26,5
#  Nom complet                        Cécile Prayer
# Département                              DELIVERY
# Code Clients                                  171
# Nom Clients                          Kering Tech
# Code Projet/Régie                            1711
# Nom Projet/Régie             KT Project Framework
# Code Phase/Mission                          17111
# Nom Phase/Mission            KT Project Framework
# Code Tâche                               171113.0
# Nom Tâche               KT S4M  Conversion to S/4
# Date de début                          01/01/2022
# Date de fin                            21/03/2022
# Temps imputé (Jours)                         26,5
# Name: 16, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Cécile Prayer
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 171
# colum name : Nom Clients -> <class 'str'> -> Kering Tech
# colum name : Code Projet/Régie -> <class 'int'> -> 1711
# colum name : Nom Projet/Régie -> <class 'str'> -> KT Project Framework
# colum name : Code Phase/Mission -> <class 'int'> -> 17111
# colum name : Nom Phase/Mission -> <class 'str'> -> KT Project Framework
# colum name : Code Tâche -> <class 'float'> -> 171114.0
# colum name : Nom Tâche -> <class 'str'> -> KT SAP Smart ToolBox
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 2,25
#  Nom complet                   Cécile Prayer
# Département                         DELIVERY
# Code Clients                             171
# Nom Clients                     Kering Tech
# Code Projet/Régie                       1711
# Nom Projet/Régie        KT Project Framework
# Code Phase/Mission                     17111
# Nom Phase/Mission       KT Project Framework
# Code Tâche                          171114.0
# Nom Tâche               KT SAP Smart ToolBox
# Date de début                     01/01/2022
# Date de fin                       21/03/2022
# Temps imputé (Jours)                    2,25
# Name: 17, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Jorge Regada
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 171
# colum name : Nom Clients -> <class 'str'> -> Kering Tech
# colum name : Code Projet/Régie -> <class 'int'> -> 1711
# colum name : Nom Projet/Régie -> <class 'str'> -> KT Project Framework
# colum name : Code Phase/Mission -> <class 'int'> -> 17111
# colum name : Nom Phase/Mission -> <class 'str'> -> KT Project Framework
# colum name : Code Tâche -> <class 'float'> -> 171113.0
# colum name : Nom Tâche -> <class 'str'> -> KT S4M  Conversion to S/4
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 19
#  Nom complet                         Jorge Regada
# Département                              DELIVERY
# Code Clients                                  171
# Nom Clients                          Kering Tech
# Code Projet/Régie                            1711
# Nom Projet/Régie             KT Project Framework
# Code Phase/Mission                          17111
# Nom Phase/Mission            KT Project Framework
# Code Tâche                               171113.0
# Nom Tâche               KT S4M  Conversion to S/4
# Date de début                          01/01/2022
# Date de fin                            21/03/2022
# Temps imputé (Jours)                           19
# Name: 18, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Jorge Regada
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 3
# colum name : Nom Clients -> <class 'str'> -> Hors Smart-Capital/ Cloudixio
# colum name : Code Projet/Régie -> <class 'int'> -> 31
# colum name : Nom Projet/Régie -> <class 'str'> -> Hors Smart-Capital / CloudixIO
# colum name : Code Phase/Mission -> <class 'int'> -> 311
# colum name : Nom Phase/Mission -> <class 'str'> -> Hors Smart-Capital / CloudixIO
# colum name : Code Tâche -> <class 'float'> -> 3111.0
# colum name : Nom Tâche -> <class 'str'> -> Hors SmartCapital / CloudixIO
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 8
#  Nom complet                              Jorge Regada
# Département                                   DELIVERY
# Code Clients                                         3
# Nom Clients              Hors Smart-Capital/ Cloudixio
# Code Projet/Régie                                   31
# Nom Projet/Régie        Hors Smart-Capital / CloudixIO
# Code Phase/Mission                                 311
# Nom Phase/Mission       Hors Smart-Capital / CloudixIO
# Code Tâche                                      3111.0
# Nom Tâche                Hors SmartCapital / CloudixIO
# Date de début                               01/01/2022
# Date de fin                                 21/03/2022
# Temps imputé (Jours)                                 8
# Name: 19, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Olivier Ricart
# colum name : Département -> <class 'str'> -> CONSEIL
# colum name : Code Clients -> <class 'int'> -> 65
# colum name : Nom Clients -> <class 'str'> -> Trajan Capital
# colum name : Code Projet/Régie -> <class 'int'> -> 651
# colum name : Nom Projet/Régie -> <class 'str'> -> Kraft - DD digitale
# colum name : Code Phase/Mission -> <class 'int'> -> 6511
# colum name : Nom Phase/Mission -> <class 'str'> -> Kraft - Due Diligence Digitale
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 4,5
#  Nom complet                            Olivier Ricart
# Département                                    CONSEIL
# Code Clients                                        65
# Nom Clients                             Trajan Capital
# Code Projet/Régie                                  651
# Nom Projet/Régie                   Kraft - DD digitale
# Code Phase/Mission                                6511
# Nom Phase/Mission       Kraft - Due Diligence Digitale
# Code Tâche                                         0.0
# Nom Tâche
# Date de début                               01/01/2022
# Date de fin                                 21/03/2022
# Temps imputé (Jours)                               4,5
# Name: 20, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Olivier Ricart
# colum name : Département -> <class 'str'> -> CONSEIL
# colum name : Code Clients -> <class 'int'> -> 130
# colum name : Nom Clients -> <class 'str'> -> OneManSupport
# colum name : Code Projet/Régie -> <class 'int'> -> 1301
# colum name : Nom Projet/Régie -> <class 'str'> -> Groupe Bourdoncle
# colum name : Code Phase/Mission -> <class 'int'> -> 13011
# colum name : Nom Phase/Mission -> <class 'str'> -> Structuration fonction IT
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 13
#  Nom complet                       Olivier Ricart
# Département                               CONSEIL
# Code Clients                                  130
# Nom Clients                         OneManSupport
# Code Projet/Régie                            1301
# Nom Projet/Régie                Groupe Bourdoncle
# Code Phase/Mission                          13011
# Nom Phase/Mission       Structuration fonction IT
# Code Tâche                                    0.0
# Nom Tâche
# Date de début                          01/01/2022
# Date de fin                            21/03/2022
# Temps imputé (Jours)                           13
# Name: 21, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Olivier Ricart
# colum name : Département -> <class 'str'> -> CONSEIL
# colum name : Code Clients -> <class 'int'> -> 30
# colum name : Nom Clients -> <class 'str'> -> Jutheau Husson
# colum name : Code Projet/Régie -> <class 'int'> -> 301
# colum name : Nom Projet/Régie -> <class 'str'> -> Assistance DSI
# colum name : Code Phase/Mission -> <class 'int'> -> 3011
# colum name : Nom Phase/Mission -> <class 'str'> -> Assistance DSI OR
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 15,5
#  Nom complet               Olivier Ricart
# Département                       CONSEIL
# Code Clients                           30
# Nom Clients                Jutheau Husson
# Code Projet/Régie                     301
# Nom Projet/Régie           Assistance DSI
# Code Phase/Mission                   3011
# Nom Phase/Mission       Assistance DSI OR
# Code Tâche                            0.0
# Nom Tâche
# Date de début                  01/01/2022
# Date de fin                    21/03/2022
# Temps imputé (Jours)                 15,5
# Name: 22, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Olivier Ricart
# colum name : Département -> <class 'str'> -> CONSEIL
# colum name : Code Clients -> <class 'int'> -> 1
# colum name : Nom Clients -> <class 'str'> -> Cloudixio
# colum name : Code Projet/Régie -> <class 'int'> -> 16
# colum name : Nom Projet/Régie -> <class 'str'> -> Recrutement - RH
# colum name : Code Phase/Mission -> <class 'int'> -> 161
# colum name : Nom Phase/Mission -> <class 'str'> -> Recrutement - RH
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 2
#  Nom complet              Olivier Ricart
# Département                      CONSEIL
# Code Clients                           1
# Nom Clients                    Cloudixio
# Code Projet/Régie                     16
# Nom Projet/Régie        Recrutement - RH
# Code Phase/Mission                   161
# Nom Phase/Mission       Recrutement - RH
# Code Tâche                           0.0
# Nom Tâche
# Date de début                 01/01/2022
# Date de fin                   21/03/2022
# Temps imputé (Jours)                   2
# Name: 23, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Olivier Ricart
# colum name : Département -> <class 'str'> -> CONSEIL
# colum name : Code Clients -> <class 'int'> -> 1
# colum name : Nom Clients -> <class 'str'> -> Cloudixio
# colum name : Code Projet/Régie -> <class 'int'> -> 13
# colum name : Nom Projet/Régie -> <class 'str'> -> BU Software
# colum name : Code Phase/Mission -> <class 'int'> -> 132
# colum name : Nom Phase/Mission -> <class 'str'> -> Westaff
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 3,25
#  Nom complet            Olivier Ricart
# Département                    CONSEIL
# Code Clients                         1
# Nom Clients                  Cloudixio
# Code Projet/Régie                   13
# Nom Projet/Régie           BU Software
# Code Phase/Mission                 132
# Nom Phase/Mission              Westaff
# Code Tâche                         0.0
# Nom Tâche
# Date de début               01/01/2022
# Date de fin                 21/03/2022
# Temps imputé (Jours)              3,25
# Name: 24, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Olivier Ricart
# colum name : Département -> <class 'str'> -> CONSEIL
# colum name : Code Clients -> <class 'int'> -> 1
# colum name : Nom Clients -> <class 'str'> -> Cloudixio
# colum name : Code Projet/Régie -> <class 'int'> -> 18
# colum name : Nom Projet/Régie -> <class 'str'> -> Marketing
# colum name : Code Phase/Mission -> <class 'int'> -> 182
# colum name : Nom Phase/Mission -> <class 'str'> -> Marketing
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 2,5
#  Nom complet            Olivier Ricart
# Département                    CONSEIL
# Code Clients                         1
# Nom Clients                  Cloudixio
# Code Projet/Régie                   18
# Nom Projet/Régie             Marketing
# Code Phase/Mission                 182
# Nom Phase/Mission            Marketing
# Code Tâche                         0.0
# Nom Tâche
# Date de début               01/01/2022
# Date de fin                 21/03/2022
# Temps imputé (Jours)               2,5
# Name: 25, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Olivier Ricart
# colum name : Département -> <class 'str'> -> CONSEIL
# colum name : Code Clients -> <class 'int'> -> 1
# colum name : Nom Clients -> <class 'str'> -> Cloudixio
# colum name : Code Projet/Régie -> <class 'int'> -> 15
# colum name : Nom Projet/Régie -> <class 'str'> -> Avant-vente/commercial
# colum name : Code Phase/Mission -> <class 'int'> -> 151
# colum name : Nom Phase/Mission -> <class 'str'> -> Avant-vente/commercial
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 0,25
#  Nom complet                    Olivier Ricart
# Département                            CONSEIL
# Code Clients                                 1
# Nom Clients                          Cloudixio
# Code Projet/Régie                           15
# Nom Projet/Régie        Avant-vente/commercial
# Code Phase/Mission                         151
# Nom Phase/Mission       Avant-vente/commercial
# Code Tâche                                 0.0
# Nom Tâche
# Date de début                       01/01/2022
# Date de fin                         21/03/2022
# Temps imputé (Jours)                      0,25
# Name: 26, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Raymond Salmon
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 171
# colum name : Nom Clients -> <class 'str'> -> Kering Tech
# colum name : Code Projet/Régie -> <class 'int'> -> 1711
# colum name : Nom Projet/Régie -> <class 'str'> -> KT Project Framework
# colum name : Code Phase/Mission -> <class 'int'> -> 17111
# colum name : Nom Phase/Mission -> <class 'str'> -> KT Project Framework
# colum name : Code Tâche -> <class 'float'> -> 171113.0
# colum name : Nom Tâche -> <class 'str'> -> KT S4M  Conversion to S/4
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 24,5
#  Nom complet                       Raymond Salmon
# Département                              DELIVERY
# Code Clients                                  171
# Nom Clients                          Kering Tech
# Code Projet/Régie                            1711
# Nom Projet/Régie             KT Project Framework
# Code Phase/Mission                          17111
# Nom Phase/Mission            KT Project Framework
# Code Tâche                               171113.0
# Nom Tâche               KT S4M  Conversion to S/4
# Date de début                          01/01/2022
# Date de fin                            21/03/2022
# Temps imputé (Jours)                         24,5
# Name: 27, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Raymond Salmon
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 171
# colum name : Nom Clients -> <class 'str'> -> Kering Tech
# colum name : Code Projet/Régie -> <class 'int'> -> 1711
# colum name : Nom Projet/Régie -> <class 'str'> -> KT Project Framework
# colum name : Code Phase/Mission -> <class 'int'> -> 17111
# colum name : Nom Phase/Mission -> <class 'str'> -> KT Project Framework
# colum name : Code Tâche -> <class 'float'> -> 171114.0
# colum name : Nom Tâche -> <class 'str'> -> KT SAP Smart ToolBox
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 16,5
#  Nom complet                  Raymond Salmon
# Département                         DELIVERY
# Code Clients                             171
# Nom Clients                     Kering Tech
# Code Projet/Régie                       1711
# Nom Projet/Régie        KT Project Framework
# Code Phase/Mission                     17111
# Nom Phase/Mission       KT Project Framework
# Code Tâche                          171114.0
# Nom Tâche               KT SAP Smart ToolBox
# Date de début                     01/01/2022
# Date de fin                       21/03/2022
# Temps imputé (Jours)                    16,5
# Name: 28, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Léonard Sené
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 1
# colum name : Nom Clients -> <class 'str'> -> Cloudixio
# colum name : Code Projet/Régie -> <class 'int'> -> 12
# colum name : Nom Projet/Régie -> <class 'str'> -> Partenariat Leapwork
# colum name : Code Phase/Mission -> <class 'int'> -> 121
# colum name : Nom Phase/Mission -> <class 'str'> -> Formation Leapwork
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 2,5
#  Nom complet                    Léonard Sené
# Département                         DELIVERY
# Code Clients                               1
# Nom Clients                        Cloudixio
# Code Projet/Régie                         12
# Nom Projet/Régie        Partenariat Leapwork
# Code Phase/Mission                       121
# Nom Phase/Mission         Formation Leapwork
# Code Tâche                               0.0
# Nom Tâche
# Date de début                     01/01/2022
# Date de fin                       21/03/2022
# Temps imputé (Jours)                     2,5
# Name: 29, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Léonard Sené
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 1
# colum name : Nom Clients -> <class 'str'> -> Cloudixio
# colum name : Code Projet/Régie -> <class 'int'> -> 13
# colum name : Nom Projet/Régie -> <class 'str'> -> BU Software
# colum name : Code Phase/Mission -> <class 'int'> -> 134
# colum name : Nom Phase/Mission -> <class 'str'> -> Smart Toolbox
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 30,5
#  Nom complet             Léonard Sené
# Département                  DELIVERY
# Code Clients                        1
# Nom Clients                 Cloudixio
# Code Projet/Régie                  13
# Nom Projet/Régie          BU Software
# Code Phase/Mission                134
# Nom Phase/Mission       Smart Toolbox
# Code Tâche                        0.0
# Nom Tâche
# Date de début              01/01/2022
# Date de fin                21/03/2022
# Temps imputé (Jours)             30,5
# Name: 30, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Marc-Antoine Sené
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 171
# colum name : Nom Clients -> <class 'str'> -> Kering Tech
# colum name : Code Projet/Régie -> <class 'int'> -> 1711
# colum name : Nom Projet/Régie -> <class 'str'> -> KT Project Framework
# colum name : Code Phase/Mission -> <class 'int'> -> 17111
# colum name : Nom Phase/Mission -> <class 'str'> -> KT Project Framework
# colum name : Code Tâche -> <class 'float'> -> 171114.0
# colum name : Nom Tâche -> <class 'str'> -> KT SAP Smart ToolBox
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 2,75
#  Nom complet               Marc-Antoine Sené
# Département                         DELIVERY
# Code Clients                             171
# Nom Clients                     Kering Tech
# Code Projet/Régie                       1711
# Nom Projet/Régie        KT Project Framework
# Code Phase/Mission                     17111
# Nom Phase/Mission       KT Project Framework
# Code Tâche                          171114.0
# Nom Tâche               KT SAP Smart ToolBox
# Date de début                     01/01/2022
# Date de fin                       21/03/2022
# Temps imputé (Jours)                    2,75
# Name: 31, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Marc-Antoine Sené
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 171
# colum name : Nom Clients -> <class 'str'> -> Kering Tech
# colum name : Code Projet/Régie -> <class 'int'> -> 1711
# colum name : Nom Projet/Régie -> <class 'str'> -> KT Project Framework
# colum name : Code Phase/Mission -> <class 'int'> -> 17111
# colum name : Nom Phase/Mission -> <class 'str'> -> KT Project Framework
# colum name : Code Tâche -> <class 'float'> -> 171113.0
# colum name : Nom Tâche -> <class 'str'> -> KT S4M  Conversion to S/4
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 7,5
#  Nom complet                    Marc-Antoine Sené
# Département                              DELIVERY
# Code Clients                                  171
# Nom Clients                          Kering Tech
# Code Projet/Régie                            1711
# Nom Projet/Régie             KT Project Framework
# Code Phase/Mission                          17111
# Nom Phase/Mission            KT Project Framework
# Code Tâche                               171113.0
# Nom Tâche               KT S4M  Conversion to S/4
# Date de début                          01/01/2022
# Date de fin                            21/03/2022
# Temps imputé (Jours)                          7,5
# Name: 32, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Marc-Antoine Sené
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 59
# colum name : Nom Clients -> <class 'str'> -> Soletanche Freyssinet
# colum name : Code Projet/Régie -> <class 'int'> -> 591
# colum name : Nom Projet/Régie -> <class 'str'> -> Harmony Light Deployment
# colum name : Code Phase/Mission -> <class 'int'> -> 5911
# colum name : Nom Phase/Mission -> <class 'str'> -> Discovery Phase
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 22,75
#  Nom complet                   Marc-Antoine Sené
# Département                             DELIVERY
# Code Clients                                  59
# Nom Clients                Soletanche Freyssinet
# Code Projet/Régie                            591
# Nom Projet/Régie        Harmony Light Deployment
# Code Phase/Mission                          5911
# Nom Phase/Mission                Discovery Phase
# Code Tâche                                   0.0
# Nom Tâche
# Date de début                         01/01/2022
# Date de fin                           21/03/2022
# Temps imputé (Jours)                       22,75
# Name: 33, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Pierre Sordoillet
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 155
# colum name : Nom Clients -> <class 'str'> -> Les Compagnons
# colum name : Code Projet/Régie -> <class 'int'> -> 1551
# colum name : Nom Projet/Régie -> <class 'str'> -> Pilotage DSI Les Compagnons
# colum name : Code Phase/Mission -> <class 'int'> -> 15512
# colum name : Nom Phase/Mission -> <class 'str'> -> Consultant PSO
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 21
#  Nom complet                      Pierre Sordoillet
# Département                                DELIVERY
# Code Clients                                    155
# Nom Clients                          Les Compagnons
# Code Projet/Régie                              1551
# Nom Projet/Régie        Pilotage DSI Les Compagnons
# Code Phase/Mission                            15512
# Nom Phase/Mission                    Consultant PSO
# Code Tâche                                      0.0
# Nom Tâche
# Date de début                            01/01/2022
# Date de fin                              21/03/2022
# Temps imputé (Jours)                             21
# Name: 34, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Damien Tardieu
# colum name : Département -> <class 'str'> -> CONSEIL
# colum name : Code Clients -> <class 'int'> -> 30
# colum name : Nom Clients -> <class 'str'> -> Jutheau Husson
# colum name : Code Projet/Régie -> <class 'int'> -> 301
# colum name : Nom Projet/Régie -> <class 'str'> -> Assistance DSI
# colum name : Code Phase/Mission -> <class 'int'> -> 3012
# colum name : Nom Phase/Mission -> <class 'str'> -> Mission projet JHSI - DT
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 40
#  Nom complet                      Damien Tardieu
# Département                              CONSEIL
# Code Clients                                  30
# Nom Clients                       Jutheau Husson
# Code Projet/Régie                            301
# Nom Projet/Régie                  Assistance DSI
# Code Phase/Mission                          3012
# Nom Phase/Mission       Mission projet JHSI - DT
# Code Tâche                                   0.0
# Nom Tâche
# Date de début                         01/01/2022
# Date de fin                           21/03/2022
# Temps imputé (Jours)                          40
# Name: 35, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Aurélien Vion
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 170
# colum name : Nom Clients -> <class 'str'> -> Pandat
# colum name : Code Projet/Régie -> <class 'int'> -> 1701
# colum name : Nom Projet/Régie -> <class 'str'> -> Mise en place roadmap Pandat
# colum name : Code Phase/Mission -> <class 'int'> -> 17012
# colum name : Nom Phase/Mission -> <class 'str'> -> Chef de projet AVI
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 43
#  Nom complet                           Aurélien Vion
# Département                                 DELIVERY
# Code Clients                                     170
# Nom Clients                                   Pandat
# Code Projet/Régie                               1701
# Nom Projet/Régie        Mise en place roadmap Pandat
# Code Phase/Mission                             17012
# Nom Phase/Mission                 Chef de projet AVI
# Code Tâche                                       0.0
# Nom Tâche
# Date de début                             01/01/2022
# Date de fin                               21/03/2022
# Temps imputé (Jours)                              43
# Name: 36, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Aurélien Vion
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 1
# colum name : Nom Clients -> <class 'str'> -> Cloudixio
# colum name : Code Projet/Régie -> <class 'int'> -> 17
# colum name : Nom Projet/Régie -> <class 'str'> -> Projet interne
# colum name : Code Phase/Mission -> <class 'int'> -> 171
# colum name : Nom Phase/Mission -> <class 'str'> -> Lucca
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 1,75
#  Nom complet             Aurélien Vion
# Département                   DELIVERY
# Code Clients                         1
# Nom Clients                  Cloudixio
# Code Projet/Régie                   17
# Nom Projet/Régie        Projet interne
# Code Phase/Mission                 171
# Nom Phase/Mission                Lucca
# Code Tâche                         0.0
# Nom Tâche
# Date de début               01/01/2022
# Date de fin                 21/03/2022
# Temps imputé (Jours)              1,75
# Name: 37, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Aurélien Vion
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 1
# colum name : Nom Clients -> <class 'str'> -> Cloudixio
# colum name : Code Projet/Régie -> <class 'int'> -> 15
# colum name : Nom Projet/Régie -> <class 'str'> -> Avant-vente/commercial
# colum name : Code Phase/Mission -> <class 'int'> -> 151
# colum name : Nom Phase/Mission -> <class 'str'> -> Avant-vente/commercial
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 1
#  Nom complet                     Aurélien Vion
# Département                           DELIVERY
# Code Clients                                 1
# Nom Clients                          Cloudixio
# Code Projet/Régie                           15
# Nom Projet/Régie        Avant-vente/commercial
# Code Phase/Mission                         151
# Nom Phase/Mission       Avant-vente/commercial
# Code Tâche                                 0.0
# Nom Tâche
# Date de début                       01/01/2022
# Date de fin                         21/03/2022
# Temps imputé (Jours)                         1
# Name: 38, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Aurélien Vion
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 1
# colum name : Nom Clients -> <class 'str'> -> Cloudixio
# colum name : Code Projet/Régie -> <class 'int'> -> 11
# colum name : Nom Projet/Régie -> <class 'str'> -> BU CRM
# colum name : Code Phase/Mission -> <class 'int'> -> 111
# colum name : Nom Phase/Mission -> <class 'str'> -> Partenariat HubSpot
# colum name : Code Tâche -> <class 'float'> -> 1111.0
# colum name : Nom Tâche -> <class 'str'> -> Mise en place partenariat HubSpot
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 0,75
#  Nom complet                                Aurélien Vion
# Département                                      DELIVERY
# Code Clients                                            1
# Nom Clients                                     Cloudixio
# Code Projet/Régie                                      11
# Nom Projet/Régie                                   BU CRM
# Code Phase/Mission                                    111
# Nom Phase/Mission                     Partenariat HubSpot
# Code Tâche                                         1111.0
# Nom Tâche               Mise en place partenariat HubSpot
# Date de début                                  01/01/2022
# Date de fin                                    21/03/2022
# Temps imputé (Jours)                                 0,75
# Name: 39, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Aurélien Vion
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 1
# colum name : Nom Clients -> <class 'str'> -> Cloudixio
# colum name : Code Projet/Régie -> <class 'int'> -> 16
# colum name : Nom Projet/Régie -> <class 'str'> -> Recrutement - RH
# colum name : Code Phase/Mission -> <class 'int'> -> 162
# colum name : Nom Phase/Mission -> <class 'str'> -> Management
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 0,25
#  Nom complet               Aurélien Vion
# Département                     DELIVERY
# Code Clients                           1
# Nom Clients                    Cloudixio
# Code Projet/Régie                     16
# Nom Projet/Régie        Recrutement - RH
# Code Phase/Mission                   162
# Nom Phase/Mission             Management
# Code Tâche                           0.0
# Nom Tâche
# Date de début                 01/01/2022
# Date de fin                   21/03/2022
# Temps imputé (Jours)                0,25
# Name: 40, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Aurélien Vion
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 1
# colum name : Nom Clients -> <class 'str'> -> Cloudixio
# colum name : Code Projet/Régie -> <class 'int'> -> 11
# colum name : Nom Projet/Régie -> <class 'str'> -> BU CRM
# colum name : Code Phase/Mission -> <class 'int'> -> 112
# colum name : Nom Phase/Mission -> <class 'str'> -> Lancement BU CRM
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 0,25
#  Nom complet               Aurélien Vion
# Département                     DELIVERY
# Code Clients                           1
# Nom Clients                    Cloudixio
# Code Projet/Régie                     11
# Nom Projet/Régie                  BU CRM
# Code Phase/Mission                   112
# Nom Phase/Mission       Lancement BU CRM
# Code Tâche                           0.0
# Nom Tâche
# Date de début                 01/01/2022
# Date de fin                   21/03/2022
# Temps imputé (Jours)                0,25
# Name: 41, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Aurélien Vion
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 170
# colum name : Nom Clients -> <class 'str'> -> Pandat
# colum name : Code Projet/Régie -> <class 'int'> -> 1702
# colum name : Nom Projet/Régie -> <class 'str'> -> Pandat - Base de Deals
# colum name : Code Phase/Mission -> <class 'int'> -> 17021
# colum name : Nom Phase/Mission -> <class 'str'> -> Design Sprint
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 1
#  Nom complet                     Aurélien Vion
# Département                           DELIVERY
# Code Clients                               170
# Nom Clients                             Pandat
# Code Projet/Régie                         1702
# Nom Projet/Régie        Pandat - Base de Deals
# Code Phase/Mission                       17021
# Nom Phase/Mission                Design Sprint
# Code Tâche                                 0.0
# Nom Tâche
# Date de début                       01/01/2022
# Date de fin                         21/03/2022
# Temps imputé (Jours)                         1
# Name: 42, dtype: object
# -----------------------------------
# colum name :  Nom complet -> <class 'str'> -> Aurélien Vion
# colum name : Département -> <class 'str'> -> DELIVERY
# colum name : Code Clients -> <class 'int'> -> 1
# colum name : Nom Clients -> <class 'str'> -> Cloudixio
# colum name : Code Projet/Régie -> <class 'int'> -> 12
# colum name : Nom Projet/Régie -> <class 'str'> -> Partenariat Leapwork
# colum name : Code Phase/Mission -> <class 'int'> -> 122
# colum name : Nom Phase/Mission -> <class 'str'> -> Gestion partenariat Leapwork
# colum name : Code Tâche -> <class 'float'> -> 0.0
# colum name : Nom Tâche -> <class 'str'> ->
# colum name : Date de début -> <class 'str'> -> 01/01/2022
# colum name : Date de fin -> <class 'str'> -> 21/03/2022
# colum name : Temps imputé (Jours) -> <class 'str'> -> 0,5
#  Nom complet                           Aurélien Vion
# Département                                 DELIVERY
# Code Clients                                       1
# Nom Clients                                Cloudixio
# Code Projet/Régie                                 12
# Nom Projet/Régie                Partenariat Leapwork
# Code Phase/Mission                               122
# Nom Phase/Mission       Gestion partenariat Leapwork
# Code Tâche                                       0.0
# Nom Tâche
# Date de début                             01/01/2022
# Date de fin                               21/03/2022
# Temps imputé (Jours)                             0,5
# Name: 43, dtype: object
# -----------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_172824/1567559144.py in <module>
#      35 #    print("Nom Complet -> "+ row["Département"])
#      36 #Code Clients;Nom Clients;Code Projet/Régie;Nom Projet/Régie;Code Phase/Mission;Nom Phase/Mission;Code Tâche;Nom Tâche;Date de début;Date de fin;Temps imputé (Jours)
# ---> 37 cur.close()
#      38 conn.commit()
#
# NameError: name 'cur' is not defined
